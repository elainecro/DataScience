# %%
#concorrência - Códigos adaptados de [FORBES, Elliot. Learning Concurrency in Python: Build highly efficient, robust, and concurrent applications. 2017.]

# %%
#identificando a quantidade de núcleos disponíveis para o sistema
import multiprocessing
multiprocessing.cpu_count() #conta a quantidade de núcleos disponíveis no sistema
# Out:
# 8

# %%
#processamento sequencial
import threading  #módulo para a construção de threads
import urllib.request  #módulo para a requisição de url
import time  #módulo para tratar tempo

#função criada para a realização do download das imagens
def downloadImagens(imagePath, fileName):
    print("Realizando o download .... ", imagePath)
    urllib.request.urlretrieve(imagePath, fileName)  #realiza a requisição para a página da web


t0 = time.time() #armazena o tempo inicial de execução
for i in range(10):
    imageName = "imagens/image-" + str(i) + ".jpg"  #coloca o nome em cada uma das imagens baixadas
    downloadImagens("https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg", imageName)  #aplica o download da imagem

t1 = time.time() #tempo final após a execução
totalTime = t1 - t0  #diferença de tempo entre o valor inical de execução e o final
print("Tempo total de execução {}".format(totalTime))
# Out:
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Tempo total de execução 2.941497802734375

# %%
#exedcução do download de imagens via multiplas threads
import threading
import urllib.request
import time

def downloadImagens(imagePath, fileName):
    print("Realizando o download .... ", imagePath)
    urllib.request.urlretrieve(imagePath, fileName)
    print("Download Finalizado")

def executeThread(i): 
    imageName = "imagens_thread/image-" + str(i) + ".jpg"
    downloadImagens("https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg", imageName)


t0 = time.time()

threads = [] #lista vazia que vai conter todas as threads criadas

#cria das 10 threads, cada uma delas será responsável por realizar o download
for i in range(10):
    thread = threading.Thread(target=executeThread, args=(i,))
    threads.append(thread)
    thread.start()
    
#garante que as execuções foram finalizadas
for i in threads:
    i.join()

#calcula o tempo de execução
t1 = time.time()
totalTime = t1 - t0
print("Tempo total de execução {}".format(totalTime))
# Out:
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpgRealizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
#
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Realizando o download ....  https://aventurasnahistoria.uol.com.br/media/_versions/fridahqudnna_widelg.jpg
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download Finalizado
# Download FinalizadoDownload Finalizado
#
# Tempo total de execução 0.4487307071685791

# %% [markdown]
# **Compartilhamento de tempo**

# %%
import threading  #módulo para a construção de multithreads
import time  #módulo para a medição de tempo
import random  #módulo para geração de números randomicos

counter = 10   #contador inicial

#função que adiciona um número para o contador
def tarefaA():
    global counter  #variável global 
    while counter < 30:
        counter += 1  #incrementa o contador
        print("A tarefaA incrementou o contador para {}".format(counter))
        sleepTime = random.randint(0,3) #escolhe, randomicamente, um valor entre 0 e 3
        time.sleep(sleepTime) #coloca a tread para dormir

#função que retira um número do contador
def tarefaB():
    global counter #variável global
    while counter > -30:
        counter -= 1  #decrementa o contador
        print("A tarefaB decrementou o contador para {}".format(counter))
        sleepTime = random.randint(0,3) #escolhe, randomicamente, um valor entre 0 e 3
        time.sleep(sleepTime) #coloca a tread para dormir


t0 = time.time()
thread1 = threading.Thread(target=tarefaA) #instancia um objeto da classe Thread para executar
                                           #a tarefaA
thread2 = threading.Thread(target=tarefaB) #instancia um objeto da classe Thread para executar
                                           #a tarefaB

thread1.start() #inicia a tread1
thread2.start() #inicia thread2

thread1.join()  #ceritifica o fim da execução
thread2.join() #certifica do fim da execução

t1 = time.time()

print("Tempo total de execução {}".format(t1-t0))
# Out:
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaA incrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaB decrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12A tarefaA incrementou o contador para 13
#
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11A tarefaA incrementou o contador para 12
#
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7A tarefaA incrementou o contador para 8
#
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8A tarefaB decrementou o contador para 7
#
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3A tarefaA incrementou o contador para 4
#
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5A tarefaB decrementou o contador para 4
#
# A tarefaA incrementou o contador para 5A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
#
# A tarefaA incrementou o contador para 6A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
#
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5A tarefaA incrementou o contador para 6
#
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaA incrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaA incrementou o contador para 10
# A tarefaB decrementou o contador para 9
# A tarefaB decrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaA incrementou o contador para 8
# A tarefaB decrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaA incrementou o contador para 6
# A tarefaA incrementou o contador para 7
# A tarefaB decrementou o contador para 6
# A tarefaB decrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaA incrementou o contador para 3
# A tarefaA incrementou o contador para 4
# A tarefaA incrementou o contador para 5
# A tarefaB decrementou o contador para 4
# A tarefaB decrementou o contador para 3
# A tarefaB decrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1A tarefaB decrementou o contador para 0
#
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaA incrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaA incrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaA incrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaA incrementou o contador para -4
# A tarefaA incrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaA incrementou o contador para 2
# A tarefaB decrementou o contador para 1
# A tarefaA incrementou o contador para 2A tarefaB decrementou o contador para 1
#
# A tarefaB decrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaA incrementou o contador para 1
# A tarefaB decrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaA incrementou o contador para 0
# A tarefaB decrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaA incrementou o contador para -4
# A tarefaA incrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaA incrementou o contador para -2
# A tarefaA incrementou o contador para -1
# A tarefaB decrementou o contador para -2
# A tarefaB decrementou o contador para -3
# A tarefaB decrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaA incrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaA incrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaA incrementou o contador para -4
# A tarefaB decrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaA incrementou o contador para -5
# A tarefaB decrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaA incrementou o contador para -7
# A tarefaA incrementou o contador para -6
# A tarefaB decrementou o contador para -7
# A tarefaB decrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaB decrementou o contador para -11
# A tarefaB decrementou o contador para -12
# A tarefaB decrementou o contador para -13
# A tarefaA incrementou o contador para -12
# A tarefaB decrementou o contador para -13
# A tarefaA incrementou o contador para -12
# A tarefaB decrementou o contador para -13
# A tarefaA incrementou o contador para -12
# A tarefaA incrementou o contador para -11
# A tarefaB decrementou o contador para -12
# A tarefaA incrementou o contador para -11
# A tarefaA incrementou o contador para -10
# A tarefaB decrementou o contador para -11
# A tarefaA incrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaB decrementou o contador para -10
# A tarefaB decrementou o contador para -11
# A tarefaB decrementou o contador para -12
# A tarefaA incrementou o contador para -11
# A tarefaA incrementou o contador para -10
# A tarefaB decrementou o contador para -11
# A tarefaA incrementou o contador para -10
# A tarefaB decrementou o contador para -11
# A tarefaA incrementou o contador para -10
# A tarefaA incrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# A tarefaB decrementou o contador para -9
# A tarefaA incrementou o contador para -8
# ...
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaB decrementou o contador para 10
# A tarefaA incrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaA incrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaB decrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaB decrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaB decrementou o contador para 11
# A tarefaA incrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaB decrementou o contador para 12
# A tarefaA incrementou o contador para 13
# A tarefaA incrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaB decrementou o contador para 14
# A tarefaA incrementou o contador para 15
# A tarefaA incrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaB decrementou o contador para 16
# A tarefaA incrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaB decrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaB decrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaB decrementou o contador para 22
# A tarefaB decrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaB decrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaB decrementou o contador para 18
# A tarefaB decrementou o contador para 17
# A tarefaA incrementou o contador para 18
# A tarefaA incrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaB decrementou o contador para 19
# A tarefaA incrementou o contador para 20
# A tarefaA incrementou o contador para 21
# A tarefaA incrementou o contador para 22
# A tarefaA incrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaB decrementou o contador para 23
# A tarefaA incrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaB decrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaB decrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaB decrementou o contador para 26
# A tarefaB decrementou o contador para 25
# A tarefaB decrementou o contador para 24
# A tarefaA incrementou o contador para 25
# A tarefaA incrementou o contador para 26
# A tarefaA incrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaA incrementou o contador para 29
# A tarefaA incrementou o contador para 30
# A tarefaB decrementou o contador para 29
# A tarefaB decrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaA incrementou o contador para 29
# A tarefaB decrementou o contador para 28
# A tarefaA incrementou o contador para 29
# A tarefaA incrementou o contador para 30
# A tarefaB decrementou o contador para 29
# A tarefaB decrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaB decrementou o contador para 27
# A tarefaA incrementou o contador para 28
# A tarefaA incrementou o contador para 29
# A tarefaA incrementou o contador para 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-df4fd346ce96> in <module>
#      33 thread2.start() #inicia thread2
#      34
# ---> 35 thread1.join()  #ceritifica o fim da execução
#      36 thread2.join() #certifica do fim da execução
#      37
#
# D:\Users\elain\Anaconda3\lib\threading.py in join(self, timeout)
#    1030
#    1031         if timeout is None:
# -> 1032             self._wait_for_tstate_lock()
#    1033         else:
#    1034             # the behavior of a negative timeout isn't documented, but
#
# D:\Users\elain\Anaconda3\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1046         if lock is None:  # already determined that the C code is done
#    1047             assert self._is_stopped
# -> 1048         elif lock.acquire(block, timeout):
#    1049             lock.release()
#    1050             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# **Estados de execução de uma Thread**

# %%
import threading
import time

# função que, simplesmente, realiza o print de uma mensagem de execução e 
def threadWorker():
  # Neste ponto é onde ocorre a mudança do 'Runnable' para o 'Running'

  print("A thread entrou no estado 'Running'")

  # quando chamamos a função time.sleep() a 
  #thread entra para o estado de not-running
  print('A thread entrou no estado "Non-Running"')
  time.sleep(10)
  # quando a tarefa é finalizada, a thread é terminada 
  print("Execução da thread foi finalizada")
  #garbage collector



# neste momento a threada ainda "não possui estados"
#não existe alocação de recursos
print("Thread Criada")
myThread = threading.Thread(target=threadWorker)

#quando é chamado o método myThread.start(), python realiza a 
#alocação de recursos e, posteriormente, passa para o estado de
# "Start" para o "Runnable", mas sem entrar em execução.
print("Thread no estado 'Runnable'")
myThread.start()

#quando o metodo join é chamado, a thread passa para o estado
# "terminated"
myThread.join()
print("A thread está no estado de 'Terminated'")
# Out:
# Thread Criada
# Thread no estado 'Runnable'
# A thread entrou no estado 'Running'
# A thread entrou no estado "Non-Running"
# Execução da thread foi finalizada
# A thread está no estado de 'Terminated'

# %% [markdown]
# **Outro exemplo de execução de uma Thread**

# %%
import threading
import time
import random

#função que recebe um número e cira uma thread
def executeThread(i):
  print("Thread {} incializada \n".format(i))
  sleepTime = random.randint(1,10)
  time.sleep(sleepTime)
  print("Thread {} finalizou a execução".format(i))

for i in range(10):
  thread = threading.Thread(target=executeThread, args=(i,))
  thread.start()

  print("Número de threads ativas:" , threading.enumerate())
# Out:
# Thread 0 incializada
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>]
# Thread 1 incializada
#
# Número de threads ativas:
#  [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>]
# Thread 2 incializada
# Número de threads ativas:
#  [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>]
# Thread 3 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>]
# Thread 4 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>]
# Thread 5 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>, <Thread(Thread-10, started 140665925863168)>]
# Thread 6 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>, <Thread(Thread-10, started 140665925863168)>, <Thread(Thread-11, started 140665917470464)>]
# Thread 7 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>, <Thread(Thread-10, started 140665925863168)>, <Thread(Thread-11, started 140665917470464)>, <Thread(Thread-12, started 140665909077760)>]
# Thread 8 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>, <Thread(Thread-10, started 140665925863168)>, <Thread(Thread-11, started 140665917470464)>, <Thread(Thread-12, started 140665909077760)>, <Thread(Thread-13, started 140665900685056)>]
# Thread 9 incializada
#
# Número de threads ativas: [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Thread(Thread-5, started 140665968088832)>, <Thread(Thread-6, started 140665959433984)>, <Thread(Thread-7, started 140665951041280)>, <Thread(Thread-8, started 140665942648576)>, <Thread(Thread-9, started 140665934255872)>, <Thread(Thread-10, started 140665925863168)>, <Thread(Thread-11, started 140665917470464)>, <Thread(Thread-12, started 140665909077760)>, <Thread(Thread-13, started 140665900685056)>, <Thread(Thread-14, started 140665892292352)>]

# %% [markdown]
# **Herança com Threads**

# %%
from threading import Thread

#define a classe como filha da classe Thread
class MinhaClasseThread(Thread):
  def __init__(self):
    print("Olá, construtor thread!!")
    Thread.__init__(self)

  #define a função run() que é chamada quando thread.start()
  def run(self):
    print("\nThread em execução.")

#instanciando um objeto da classe criada
minhaThread=MinhaClasseThread()
print("Objeto criado")
minhaThread.start()
print("Thread inicalizada")
minhaThread.join()
print("Thread finalizada")
# Out:
# Olá, construtor thread!!
# Objeto criado
#
# Thread em execução.Thread inicalizada
#
# Thread finalizada

# %% [markdown]
# **Multiplas Threads**

# %%
import threading
 
class minhaThread (threading.Thread):
    def __init__(self, threadID, nome, contador):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.nome = nome
        self.contador = contador
    def run(self):
        print("Iniciando thread %s com %d processos" %(self.name,self.contador))
        processo(self.nome, self.contador)
        print("Finalizando " + self.nome)
 
def processo(nome, contador):
    while contador:
        print( "Thread %s fazendo o processo %d" % (nome, contador))
        contador -= 1
 
# Criando as threads
thread1 = minhaThread(1, "Alice", 8)
thread2 = minhaThread(2, "Bob", 8)
 
# Comecando novas Threads
thread1.start()
thread2.start()
 
threads = []
threads.append(thread1)
threads.append(thread2)
 
for t in threads:
    t.join()
 
print("Saindo da main")
# Out:
# Iniciando thread Thread-59 com 8 processosIniciando thread Thread-60 com 8 processos
# Thread Bob fazendo o processo 8
# Thread Bob fazendo o processo 7
# Thread Bob fazendo o processo 6
# Thread Bob fazendo o processo 5
# Thread Bob fazendo o processo 4
# Thread Bob fazendo o processo 3
# Thread Bob fazendo o processo 2
# Thread Bob fazendo o processo 1
# Finalizando Bob
#
# Thread Alice fazendo o processo 8
# Thread Alice fazendo o processo 7
# Thread Alice fazendo o processo 6
# Thread Alice fazendo o processo 5
# Thread Alice fazendo o processo 4
# Thread Alice fazendo o processo 3
# Thread Alice fazendo o processo 2
# Thread Alice fazendo o processo 1
# Finalizando Alice
# Saindo da main

# %% [markdown]
# **Contando Threads ativas**

# %%
import threading
import time
import random


def minhaThread(i):
  print("Thread {}: inicializada".format(i))
  time.sleep(random.randint(1,5))
  print("\nThread {}: finalizada".format(i))

for i in range(random.randint(2,50)):
  thread=threading.Thread(target=minhaThread,args=(i,))
  thread.start()
time.sleep(4)
print("Total de Threads ativas: {}".format(threading.active_count()))
# Out:
# Thread 0: inicializadaThread 1: inicializada
#
# Thread 2: inicializada
# Thread 3: inicializada
# Thread 4: inicializada
# Thread 5: inicializada
# Thread 6: inicializada
# Thread 7: inicializada
# Thread 8: inicializada
# Thread 9: inicializada
# Thread 10: inicializada
# Thread 11: inicializada
# Thread 12: inicializada
# Thread 13: inicializada
# Thread 14: inicializada
# Thread 15: inicializada
# Thread 16: inicializada
# Thread 17: inicializada
# Thread 18: inicializada
# Thread 19: inicializada
# Thread 20: inicializada
# Thread 21: inicializada
# Thread 22: inicializada
# Thread 23: inicializada
# Thread 24: inicializada
# Thread 25: inicializada
# Thread 26: inicializada
# Thread 27: inicializada
# Thread 28: inicializada
# Thread 29: inicializada
# Thread 30: inicializada
# Thread 31: inicializada
# Thread 32: inicializada
# Thread 33: inicializada
# Thread 34: inicializada
# Thread 35: inicializada
# Thread 36: inicializada
# Thread 37: inicializadaThread 38: inicializada
#
#
# Thread 3: finalizada
#
# Thread 18: finalizada
#
# Thread 22: finalizada
# Thread 23: finalizada
#
#
# Thread 24: finalizada
#
# Thread 26: finalizada
#
# Thread 31: finalizada
#
# Thread 32: finalizada
# Thread 34: finalizada
#
#
# Thread 36: finalizada
#
# Thread 37: finalizada
#
# Thread 1: finalizada
#
# Thread 2: finalizada
#
# Thread 11: finalizada
#
# Thread 21: finalizada
#
# Thread 35: finalizada
#
# Thread 4: finalizada
# Thread 8: finalizada
#
# Thread 5: finalizada
#
#
# Thread 10: finalizada
#
# Thread 13: finalizada
#
# Thread 15: finalizada
# Thread 17: finalizada
#
#
# Thread 28: finalizada
#
# Thread 30: finalizada
#
# Thread 9: finalizada
#
# Thread 12: finalizada
# Thread 14: finalizada
#
#
# Thread 20: finalizada
# Thread 19: finalizada
#
#
# Thread 27: finalizada
#
# Thread 33: finalizada
# Total de Threads ativas: 16

# %% [markdown]
# **Em qual thread estamos?**

# %%
import threading
import time

def threadTarget():
  print("Thread atual: {}".format(threading.current_thread()))

threads = []

for i in range(10):
  thread = threading.Thread(target=threadTarget)
  thread.start()
  threads.append(thread)

for thread in threads:
  thread.join()
# Out:
# Thread atual: <Thread(Thread-100, started 140665674082048)>
# Thread atual: <Thread(Thread-101, started 140665598547712)>Thread atual: <Thread(Thread-102, started 140665674082048)>
# Thread atual: <Thread(Thread-103, started 140665707652864)>
#
# Thread atual: <Thread(Thread-104, started 140665674082048)>Thread atual: <Thread(Thread-105, started 140665707652864)>
#
# Thread atual: <Thread(Thread-106, started 140665598547712)>
# Thread atual: <Thread(Thread-107, started 140665598547712)>
# Thread atual: <Thread(Thread-108, started 140665598547712)>
# Thread atual: <Thread(Thread-109, started 140665707652864)>

# %% [markdown]
# **Main Thread**

# %%
import threading
import time

def myChildThread():
  print("Thread Filha inicializada ----")
  time.sleep(5)
  print("Thread Atual ----------")
  print(threading.current_thread())
  print("-------------------------")
  print("Main Thread -------------")
  print(threading.main_thread())
  print("-------------------------")
  print("Thread Filha Finalizada")


child = threading.Thread(target=myChildThread)
child.start()
child.join()
# Out:
# Thread Filha inicializada ----
# Thread Atual ----------
# <Thread(Thread-110, started 140665707652864)>
# -------------------------
# Main Thread -------------
# <_MainThread(MainThread, started 140666446555008)>
# -------------------------
# Thread Filha Finalizada

# %% [markdown]
# **Identificando as Threads**

# %%
import threading
import time


def myThread():
  print("Thread {} inicializada".format(threading.currentThread().getName()))
  time.sleep(10)
  print("Thread {} finalizada".format(threading.currentThread().getName()))

for i in range(4):
  threadName = "Thread-" + str(i)
  thread = threading.Thread(name=threadName, target=myThread)
  thread.start()

print("{}".format(threading.enumerate()))
# Out:
# Thread Thread-0 inicializada
# Thread Thread-1 inicializada
# Thread Thread-2 inicializada
# Thread Thread-3 inicializada
# [<_MainThread(MainThread, started 140666446555008)>, <Thread(Thread-2, started daemon 140666049492736)>, <Heartbeat(Thread-3, started daemon 140666041100032)>, <ParentPollerUnix(Thread-1, started daemon 140665976743680)>, <Filosofos(Kant, started 140665749616384)>, <Filosofos(Aristotle, started 140665850328832)>, <Filosofos(Spinoza, started 140665766401792)>, <Filosofos(Marx, started 140665732830976)>, <Filosofos(Russell, started 140665968088832)>, <Thread(Thread-0, started 140665707652864)>, <Thread(Thread-1, started 140665598547712)>, <Thread(Thread-2, started 140665674082048)>, <Thread(Thread-3, started 140665808365312)>]

# %% [markdown]
# **Deadlock**

# %%
import threading
import time
import random

class Filosofos(threading.Thread):

    def __init__(self, name, leftFork, rightFork):
        print("{} sentou na mesa".format(name))
        threading.Thread.__init__(self, name=name)
        self.leftFork = leftFork
        self.rightFork = rightFork

    def run(self):
        print("{} começou a pensar".format(threading.currentThread().getName()))
        while True:
            time.sleep(random.randint(1,5))
            print("{} parou de pensar".format(threading.currentThread().getName()))
            self.leftFork.acquire()
            time.sleep(random.randint(1,5))
            try:
                print("{} pegou o garfo da esquerda.".format(threading.currentThread().getName()))

                self.rightFork.acquire()
                try:
                    print("{} pegou os dois garfos e começou a comer".format(threading.currentThread().getName()))
                finally:
                    self.rightFork.release()   
                    print("{} soltou o garfo da direita".format(threading.currentThread().getName()))
            finally:
                self.leftFork.release()
                print("{} soltou o garfo da esquerda".format(threading.currentThread().getName()))

fork1 = threading.RLock()
fork2 = threading.RLock()
fork3 = threading.RLock()
fork4 = threading.RLock()
fork5 = threading.RLock()

philosopher1 = Filosofos("Kant", fork1, fork2)
philosopher2 = Filosofos("Aristotle", fork2, fork3)
philosopher3 = Filosofos("Spinoza", fork3, fork4)
philosopher4 = Filosofos("Marx", fork4, fork5)
philosopher5 = Filosofos("Russell", fork5, fork1)

philosopher1.start()
philosopher2.start()
philosopher3.start()
philosopher4.start()
philosopher5.start()

philosopher1.join()
philosopher2.join()
philosopher3.join()
philosopher4.join()
philosopher5.join()
# Out:
# Kant sentou na mesa
# Aristotle sentou na mesa
# Spinoza sentou na mesa
# Marx sentou na mesa
# Russell sentou na mesa
# Kant começou a pensar
# Aristotle começou a pensar
# Spinoza começou a pensar
# Marx começou a pensar
# Russell começou a pensar
# Kant parou de pensar
# Aristotle parou de pensar
# Russell parou de pensar
# Kant pegou o garfo da esquerda.
# Aristotle pegou o garfo da esquerda.
# Aristotle pegou os dois garfos e começou a comer
# Aristotle soltou o garfo da direita
# Aristotle soltou o garfo da esquerda
# Kant pegou os dois garfos e começou a comer
# Kant soltou o garfo da direita
# Kant soltou o garfo da esquerda
# Russell pegou o garfo da esquerda.
# Russell pegou os dois garfos e começou a comer
# Russell soltou o garfo da direita
# Russell soltou o garfo da esquerda
# Spinoza parou de pensarMarx parou de pensar
#
# Russell parou de pensar
# Marx pegou o garfo da esquerda.
# Kant parou de pensar
# Russell pegou o garfo da esquerda.
# Aristotle parou de pensar
# Spinoza pegou o garfo da esquerda.
# Kant pegou o garfo da esquerda.
# Aristotle pegou o garfo da esquerda.

# %% [markdown]
# **Semáforos**

# %%
import threading
import time
import random

class TicketSeller(threading.Thread):
    ticketsSold = 0

    def __init__(self, semaphore):
        threading.Thread.__init__(self);
        self.sem = semaphore
        print("Venda de ingressos inicializada")

    def run(self):
        global ticketsAvailable
        running = True
        while running:
            self.randomDelay()

            self.sem.acquire()
            if(ticketsAvailable <= 0):
                running = False
            else:
                self.ticketsSold = self.ticketsSold + 1
                ticketsAvailable = ticketsAvailable - 1
                print("{} acabou de vender 1 ({} restantes)".format(self.getName(), ticketsAvailable))
            
            self.sem.release()

        print("Venda de ingresso {} Ingressos vendidos no total {}".format(self.getName(), self.ticketsSold))

    def randomDelay(self):
        time.sleep(random.randint(0,4)/4)


# definição do nosso semáforo
semaphore = threading.Semaphore()
# Número de ingressos disponíveis
ticketsAvailable = 20

# os nossos vendedores
sellers = []
for i in range(4):
    seller = TicketSeller(semaphore)
    seller.start()
    sellers.append(seller)

# joining all our sellers
for seller in sellers:
    seller.join()

# %% [markdown]
# **Queue em Python**

# %%
#código adaptado de http://www.learn4master.com/algorithms/python-queue-for-multithreading
#  put(), get(), join() e task_done().
import threading
import time
from queue import Queue 

def consumidor(q):
    while(True):
        name = threading.currentThread().getName()
        print("Thread: {0} deseja obter um item da queue[tamanho atual = {1}] na data = {2} \n".format(name, q.qsize(), time.strftime('%H:%M:%S')))
        item = q.get();
        time.sleep(3)  # demora 3 segundos para adicionar um item
        print("Thread: {0} terminou de processar o item da queue[tamanho atual = {1}] na data = {2} \n".format(name, q.qsize(), time.strftime('%H:%M:%S')))
        q.task_done()


def produtor(q):
    # a thread principal vai adicionar itens para a queue

    for i in range(10):
        name = threading.currentThread().getName()
        print("Thread: {0} começou a adicionar um item na queue[tamanho atual = {1}] na data = {2} \n".format(name, q.qsize(), time.strftime('%H:%M:%S')))
        item = "item-" + str(i)
        q.put(item)
        print("Thread: {0} adicionou um item na queue[tamanho atual = {1}] na data = {2} \n".format(name, q.qsize(), time.strftime('%H:%M:%S')))

    q.join()

if __name__ == '__main__':
    q = Queue(maxsize = 3)

    threads_num = 3  # criação de 3 threads consumidoras
    for i in range(threads_num):
        t = threading.Thread(name = "ThreadConsumidora-"+str(i), target=consumidor, args=(q,))
        t.start()

    # criação de uma thread produtora
    t = threading.Thread(name = "ThreadProdutora", target=produtor, args=(q,))
    t.start()

    q.join()
# Out:
# Thread: ThreadConsumidora-0 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:02
#
# Thread: ThreadConsumidora-1 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:02
#
# Thread: ThreadConsumidora-2 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 0] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 1] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 1] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 3] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 3] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 2] na data = 21:40:02
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 3] na data = 21:40:02
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 3] na data = 21:40:02
#
# Thread: ThreadConsumidora-1 terminou de processar o item da queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadConsumidora-1 deseja obter um item da queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadConsumidora-2 terminou de processar o item da queue[tamanho atual = 2] na data = 21:40:05
#
# Thread: ThreadConsumidora-2 deseja obter um item da queue[tamanho atual = 2] na data = 21:40:05
#
# Thread: ThreadConsumidora-0 terminou de processar o item da queue[tamanho atual = 1] na data = 21:40:05
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 2] na data = 21:40:05
#
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 2] na data = 21:40:05
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadConsumidora-0 deseja obter um item da queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadProdutora começou a adicionar um item na queue[tamanho atual = 3] na data = 21:40:05
#
# Thread: ThreadConsumidora-1 terminou de processar o item da queue[tamanho atual = 3] na data = 21:40:08
# Thread: ThreadConsumidora-0 terminou de processar o item da queue[tamanho atual = 3] na data = 21:40:08
# Thread: ThreadConsumidora-2 terminou de processar o item da queue[tamanho atual = 3] na data = 21:40:08
#
# Thread: ThreadConsumidora-2 deseja obter um item da queue[tamanho atual = 3] na data = 21:40:08
#
#
# Thread: ThreadProdutora adicionou um item na queue[tamanho atual = 3] na data = 21:40:08
#
# Thread: ThreadConsumidora-1 deseja obter um item da queue[tamanho atual = 3] na data = 21:40:08
#
#
# Thread: ThreadConsumidora-0 deseja obter um item da queue[tamanho atual = 2] na data = 21:40:08
#
# Thread: ThreadConsumidora-2 terminou de processar o item da queue[tamanho atual = 1] na data = 21:40:11
#
# Thread: ThreadConsumidora-2 deseja obter um item da queue[tamanho atual = 1] na data = 21:40:11
#
# Thread: ThreadConsumidora-1 terminou de processar o item da queue[tamanho atual = 0] na data = 21:40:11
#
# Thread: ThreadConsumidora-1 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:11
#
# Thread: ThreadConsumidora-0 terminou de processar o item da queue[tamanho atual = 0] na data = 21:40:11
#
# Thread: ThreadConsumidora-0 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:11
#
# Thread: ThreadConsumidora-2 terminou de processar o item da queue[tamanho atual = 0] na data = 21:40:14
#
# Thread: ThreadConsumidora-2 deseja obter um item da queue[tamanho atual = 0] na data = 21:40:14
